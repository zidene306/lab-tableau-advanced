# %% [markdown]
# 1. **Choropleth Map**:
# The choropleth map shows that California has the highest number of customer

# %% [markdown]
#  2. **Regression Plot**
# form the regression plot, we can colnclude that there is no appearent trendline between Income and customer Life Time value. The R squared =0.016% assess that the relations ship is weak. The P_vlaue = 0.6 > 0.05 suggest that statically there is no association between Income and customer Life Time value.

# %% [markdown]
# 3. **Boxplot Analysis**:
# The boxplot Analysis suggests that the mean total clain amount is higher for small size vehicles. Whereas the mi-size vehiclues have the widest distribution range.

# %% [markdown]
# 4. **Dashboard Creation**
# 5. Created interactive dashboard of the three sheets.
